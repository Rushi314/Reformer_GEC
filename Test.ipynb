# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %%
#Variables
username = 'shubham-shetty'
repository = 'Reformer_GEC'
git_token = open('token.txt', 'r').readlines()[0]

# %%
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'Reformer_GEC'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.

# %%
# %cd {repository}
# Out:
# /content/drive/My Drive/Github/Reformer_GEC

# %%
# %ls -a
# Out:
#  code/   .git/        .ipynb_checkpoints/  'test (1).ipynb'
#  data/   .gitignore   README.md

# %%
# Git Commands
# !git branch
# !git checkout <branch_name>
# !git status
# !git add .
# !git commit -m "Commit Message"
# !git push

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Test.ipynb
# 	test (1).ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
